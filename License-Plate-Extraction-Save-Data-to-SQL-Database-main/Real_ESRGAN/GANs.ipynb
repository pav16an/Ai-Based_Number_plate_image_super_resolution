# %%
# !git clone https://github.com/xinntao/Real-ESRGAN.git
# Out:
# Cloning into 'Real-ESRGAN'...

# %%
# %cd Real-ESRGAN
# Out:
# d:\final_year_project\Real_ESRGAN\Real-ESRGAN
# C:\Users\ayith\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached basicsr-1.4.2-py3-none-any.whl
# ...
#   Using cached facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached gfpgan-1.3.8-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# ...
#   Using cached filterpy-1.4.5.zip (177 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached facexlib-0.3.0-py3-none-any.whl (59 kB)
# ...

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating realesrgan.egg-info
# writing realesrgan.egg-info\PKG-INFO
# writing dependency_links to realesrgan.egg-info\dependency_links.txt
# writing requirements to realesrgan.egg-info\requires.txt
# writing top-level names to realesrgan.egg-info\top_level.txt
# writing manifest file 'realesrgan.egg-info\SOURCES.txt'
# reading manifest file 'realesrgan.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'realesrgan.egg-info\SOURCES.txt'
# running build_ext
# Creating c:\users\ayith\appdata\local\programs\python\python310\lib\site-packages\realesrgan.egg-link (link to .)
# Adding realesrgan 0.3.0 to easy-install.pth file
#
# Installed d:\final_year_project\real_esrgan\real-esrgan
# Processing dependencies for realesrgan==0.3.0
# Searching for tqdm
# Reading https://pypi.org/simple/tqdm/
# ...
# Best match: tqdm 4.67.1
# Processing tqdm-4.67.1-py3-none-any.whl
# ...

# %%
# !pip install realesrgan
# Out:
# ...
#   Using cached realesrgan-0.3.0-py3-none-any.whl.metadata (17 kB)
# ...
# Using cached realesrgan-0.3.0-py3-none-any.whl (26 kB)
# ...

# %%
# Download the x4 model
# !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.5/RealESRGAN_x4plus.pth -P weights
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from realesrgan import RealESRGAN
from PIL import Image
import torch

# Load model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = RealESRGAN(device, scale=4)
model.load_weights('weights/RealESRGAN_x4plus.pth')

# Load cropped plate image
image = Image.open('data\carImage2.png').convert('RGB')

# Super-resolution
sr_image = model.predict(image)

# Save or pass it to OCR
sr_image.save('plate_sr.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from realesrgan import RealESRGAN
#       2 from PIL import Image
#       3 import torch
#
# File d:\final_year_project\Real_ESRGAN\Real-ESRGAN\realesrgan\__init__.py:2
#       1 # flake8: noqa
# ----> 2 from .archs import *
#       3 from .data import *
#       4 from .models import *
#
# File d:\final_year_project\Real_ESRGAN\Real-ESRGAN\realesrgan\archs\__init__.py:2
#       1 import importlib
# ----> 2 from basicsr.utils import scandir
#       3 from os import path as osp
#       5 # automatically scan and import arch modules for registry
#       6 # scan all the files that end with '_arch.py' under the archs folder
#
# ModuleNotFoundError: No module named 'basicsr'
